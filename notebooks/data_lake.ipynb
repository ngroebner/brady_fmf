# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import obspy.io.sac as sac
import obspy

# %%
st1 = obspy.read('https://nrel-pds-porotomo.s3.amazonaws.com/Nodal/nodal_sac/001/20160309174628184.1.EHZ.PG.sac')
st2 = obspy.read('https://nrel-pds-porotomo.s3.amazonaws.com/Nodal/nodal_sac/002/20160309172248260.2.EHZ.PG.sac')

# %%
st1.plot(type="dayplot")
st2.plot(type="dayplot")
plt.show()

# %%
st = st1+st2

# %%
st.plot();plt.show()

# %%
import h5py

# %%
with h5py.File("/Volumes/T7/datasets/len-db/LEN-DB.hdf5") as f:
    print(list(f.keys()))
    eq1_key = list(f["EQ"].keys())[0]
    print(f["EQ"][eq1_key])
# Out:
# ['AN', 'EQ', 'Stations']
# <HDF5 dataset "AE_319A_1354213304.0999": shape (3, 540), type "<f8">

# %%
eq1_key
# Out:
# 'AE_319A_1354213304.0999'
